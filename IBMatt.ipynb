# %%
import numpy as np
import matplotlib .pyplot as plt
import pandas as pd
import seaborn as sns

# %%
IBMatt = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
IBMatt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
fig, ax = plt.subplots() 
data = IBMatt['Attrition'].value_counts() 
Count = data.index 
Attrition = data.values 
ax.bar(points, frequency) 
ax.set_title('IBM Attrition') 
ax.set_xlabel('Attrition') 
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
IBMatt["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
filt = (IBMatt["Attrition"] == 'Yes')

# %%
IBMatt[filt]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
IBMatt.loc[filt, 'Age']
fig = plt.figure
bp = IBMatt.boxplot('Age','Attrition')

# %%
IBMatt['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
IBMatt['MaritalStatus'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
IBMa = IBMatt[["MonthlyIncome","Attrition"]]
IBMa.head(20)
# Out:
#     MonthlyIncome Attrition
# 0            5993       Yes
# 1            5130        No
# 2            2090       Yes
# 3            2909        No
# 4            3468        No
# 5            3068        No
# 6            2670        No
# 7            2693        No
# 8            9526        No
# 9            5237        No
# 10           2426        No
# 11           4193        No
# 12           2911        No
# 13           2661        No
# 14           2028       Yes
# 15           9980        No
# 16           3298        No
# 17           2935        No
# 18          15427        No
# 19           3944        No

# %%
IBMa.head(20)
# Out:
#     MonthlyIncome Attrition
# 0            5993       Yes
# 1            5130        No
# 2            2090       Yes
# 3            2909        No
# 4            3468        No
# 5            3068        No
# 6            2670        No
# 7            2693        No
# 8            9526        No
# 9            5237        No
# 10           2426        No
# 11           4193        No
# 12           2911        No
# 13           2661        No
# 14           2028       Yes
# 15           9980        No
# 16           3298        No
# 17           2935        No
# 18          15427        No
# 19           3944        No

# %%
dst = IBMatt[["DistanceFromHome","JobRole", "Attrition"]]
dst.describe()
# Out:
#        DistanceFromHome
# count       1470.000000
# mean           9.192517
# std            8.106864
# min            1.000000
# 25%            2.000000
# 50%            7.000000
# 75%           14.000000
# max           29.000000

# %%
IBMatt["DistanceFromHome"].value_counts()
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 29     27
# 23     27
# 18     26
# 15     26
# 20     25
# 25     25
# 26     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 13     19
# 22     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
IBMatt.loc[filt, 'JobRole']
# Out:
# 0             Sales Executive
# 2       Laboratory Technician
# 14      Laboratory Technician
# 21       Sales Representative
# 24         Research Scientist
#                 ...
# 1438     Sales Representative
# 1442       Research Scientist
# 1444    Laboratory Technician
# 1452          Sales Executive
# 1461          Sales Executive
# Name: JobRole, Length: 237, dtype: object

# %%
IBMatt["JobRole"].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
IBMatt.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
MonthlyIncome= IBMatt['MonthlyIncome']
MonthlyIncome.head(10
# Out:
# 0    5993
# 1    5130
# 2    2090
# 3    2909
# 4    3468
# 5    3068
# 6    2670
# 7    2693
# 8    9526
# 9    5237
# Name: MonthlyIncome, dtype: int64

# %%
IBM = IBMatt[["MonthlyIncome", "Attrition","Education"]]
IBM.head(10)
# Out:
#    MonthlyIncome Attrition  Education
# 0           5993       Yes          2
# 1           5130        No          1
# 2           2090       Yes          2
# 3           2909        No          4
# 4           3468        No          1
# 5           3068        No          2
# 6           2670        No          3
# 7           2693        No          1
# 8           9526        No          3
# 9           5237        No          3

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-95-c3b94480c9fd> in <module>
# ----> 1 IBMatt["Gender"].value_counts()
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
IBMatt = IBMatt.hist(column='HourlyRate', bins=12, grid=False, figsize=(12,8))

# %%
EnvironmentSatisfied = IBMatt[IBMatt["EnvironmentSatisfaction"] >2]

# %%
EnvironmentSatisfied.head(10)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# 14   28       Yes      Travel_Rarely        103  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 1                  8          1  Life Sciences              1               2
# ...

# %%
IBMatt.groupby(["Education", "Attrition"])["MonthlyIncome"].mean()
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %%
Att_Age = IBMatt[["Age","Attrition"]]
Att_Age.describe()
# Out:
#                Age
# count  1470.000000
# mean     36.923810
# std       9.135373
# min      18.000000
# 25%      30.000000
# 50%      36.000000
# 75%      43.000000
# max      60.000000
